# %% [markdown]
# # Create January Effect Annual Returns

# %% [markdown]
# How to create annual returns starting at 1st day of the year or 10th day of the year

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import datetime as dt
import sys
sys.path.insert(0, "../")
import util
from importlib import reload
util=reload(util)

# %% [markdown]
# ### Set Local Macro Variables

# %%
startyear=1990
startday=10

# %% [markdown]
# ### Read in Daily Data
# #### Daily CRSP

# %%
crsp_d = pd.read_csv('qcrspdsf_raw.csv.gz', compression='gzip', usecols=lambda x: x.lower())

crsp_d.columns = crsp_d.columns.str.lower()
crsp_d = crsp_d[['permno', 'permco', 'date', 'ret', 'retx', 'shrout', 'prc']]
crsp_d[['permno','permco']] = crsp_d[['permno','permco']].astype(int)
crsp_d['ret'] = pd.to_numeric(crsp_d['ret'], errors='coerce')
crsp_d['retx'] = pd.to_numeric(crsp_d['retx'], errors='coerce')

crsp_d['date'] = pd.to_datetime(crsp_d['date'])

crsp_d.head()
# Out:
# /Users/natejensen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    permno  permco       date       ret      retx  shrout      prc
# 0   10001    7953 1990-01-02  0.000000  0.000000  1022.0  10.1250
# 1   10001    7953 1990-01-03 -0.012346 -0.012346  1022.0  10.0000
# 2   10001    7953 1990-01-04  0.000000  0.000000  1022.0  10.0000
# 3   10001    7953 1990-01-05  0.006250  0.006250  1022.0 -10.0625
# 4   10001    7953 1990-01-08  0.006211  0.006211  1022.0  10.1250

# %% [markdown]
# #### CRSP Daily Stock Event - Delisting

# %%
qcrspdse_raw = pd.read_csv('qcrspdse_raw.csv.gz', compression='gzip')

qcrspdse_raw = qcrspdse_raw[['permno', 'shrcd', 'exchcd', 'namedt', 'nameendt']]

qcrspdse_raw[['permno','shrcd','exchcd']] = qcrspdse_raw[['permno','shrcd','exchcd']].astype(int)
qcrspdse_raw = qcrspdse_raw[qcrspdse_raw['exchcd'].isin([1, 2, 3])]
qcrspdse_raw = qcrspdse_raw[qcrspdse_raw['shrcd'].isin([10, 11])]

qcrspdse_raw['namedt'] = pd.to_datetime(qcrspdse_raw['namedt'])
qcrspdse_raw['nameendt'] = pd.to_datetime(qcrspdse_raw['nameendt'])

qcrspdse_raw.head()
# Out:
#    permno  shrcd  exchcd     namedt   nameendt
# 0   10000     10       3 1986-01-07 1986-12-03
# 1   10000     10       3 1986-12-04 1987-03-09
# 2   10000     10       3 1987-03-10 1987-06-11
# 3   10001     11       3 1986-01-09 1993-11-21
# 4   10001     11       3 1993-11-22 2004-06-09

# %% [markdown]
# ##### Join daily stock data with name history

# %%
crsp_d = crsp_d.merge(qcrspdse_raw, on='permno', how='left')

crsp_d = crsp_d[(crsp_d.namedt <= crsp_d.date) & (crsp_d.date <= crsp_d.nameendt)]

crsp_d.head()
# Out:
#     permno  permco       date       ret      retx  shrout      prc  shrcd  \
# 0    10001    7953 1990-01-02  0.000000  0.000000  1022.0  10.1250   11.0
# 10   10001    7953 1990-01-03 -0.012346 -0.012346  1022.0  10.0000   11.0
# 20   10001    7953 1990-01-04  0.000000  0.000000  1022.0  10.0000   11.0
# 30   10001    7953 1990-01-05  0.006250  0.006250  1022.0 -10.0625   11.0
# 40   10001    7953 1990-01-08  0.006211  0.006211  1022.0  10.1250   11.0
#
#     exchcd     namedt   nameendt
# 0      3.0 1986-01-09 1993-11-21
# 10     3.0 1986-01-09 1993-11-21
# 20     3.0 1986-01-09 1993-11-21
# 30     3.0 1986-01-09 1993-11-21
# 40     3.0 1986-01-09 1993-11-21

# %% [markdown]
# #### CRSP Daily Stock Event - Delisting

# %%
dlret = pd.read_csv('qdlretd_raw.csv.gz', compression='gzip')

dlret = dlret[['permno', 'dlret', 'dlstdt']]

dlret[['permno']] = dlret[['permno']].astype(int)

dlret['date'] = pd.to_datetime(dlret['dlstdt'])

dlret.head()
# Out:
#    permno     dlret      dlstdt       date
# 0   10000  0.000000  1987-06-11 1987-06-11
# 1   10001  0.000000  2017-08-03 2017-08-03
# 2   10002  0.010906  2013-02-15 2013-02-15
# 3   10003 -0.003648  1995-12-15 1995-12-15
# 4   10004       NaN  1986-01-17 1986-01-17

# %% [markdown]
# ##### Format Dates

# %%
crsp_d = util.jdate(crsp_d)
dlret = util.jdate(dlret)

# %%
crsp = util.comebineRet(crsp_d,dlret)

crsp.head()
# Out:
#    permno  permco       ret      retx  shrout      prc  shrcd  exchcd  \
# 0   10001    7953  0.000000  0.000000  1022.0  10.1250   11.0     3.0
# 1   10001    7953 -0.012346 -0.012346  1022.0  10.0000   11.0     3.0
# 2   10001    7953  0.000000  0.000000  1022.0  10.0000   11.0     3.0
# 3   10001    7953  0.006250  0.006250  1022.0 -10.0625   11.0     3.0
# 4   10001    7953  0.006211  0.006211  1022.0  10.1250   11.0     3.0
#
#       namedt   nameendt      jdate  dlret dlstdt    retadj   retxadj
# 0 1986-01-09 1993-11-21 1990-01-02    0.0    NaN  0.000000  0.000000
# 1 1986-01-09 1993-11-21 1990-01-03    0.0    NaN -0.012346 -0.012346
# 2 1986-01-09 1993-11-21 1990-01-04    0.0    NaN  0.000000  0.000000
# 3 1986-01-09 1993-11-21 1990-01-05    0.0    NaN  0.006250  0.006250
# 4 1986-01-09 1993-11-21 1990-01-08    0.0    NaN  0.006211  0.006211

# %%
crsp['month']=crsp['jdate'].dt.month
crsp['year']=crsp['jdate'].dt.year

# %%
crsp = crsp[~(crsp['year']<startyear)]

# %%
crsp = crsp.sort_values('jdate')

# %%
crsp = util.annRet(crsp)

# %%
crsp['daycount'] = crsp['jdate'].dt.dayofyear

# %%
crsp2 = crsp.copy()

# %%
crsp2 = crsp2[~(crsp2['daycount']<startday)]

# %%
# Create annual return data set
crsp2=crsp2.sort_values(['permno','jdate'],ascending=[True,True])
crsp2['annRet10'] = crsp2.groupby(['permno','year'])['1+retadj'].cumprod()-1

# %%
crsp2 = crsp2[~(crsp2['month']!=12)]

# %%
crsp3 = crsp2.drop_duplicates(['permno','year'],keep='last')

# %%
crsp3[crsp3['permno']==14593].tail()
# Out:
#          permno  permco       ret      retx      shrout        prc  shrcd  \
# 5216065   14593       7 -0.007796 -0.007796   5257816.0  115.82000   11.0
# 5216316   14593       7 -0.010814 -0.010814   5087056.0  169.23000   11.0
# 5216567   14593       7  0.009665  0.009665   4729803.0  157.74001   11.0
# 5216819   14593       7  0.007307  0.007307   4384959.0  293.64999   11.0
# 5217072   14593       7 -0.007703 -0.007703  17001802.0  132.69000   11.0
#
#          exchcd     namedt   nameendt  ... dlret  dlstdt    retadj   retxadj  \
# 5216065     3.0 2007-01-11 2017-12-27  ...   0.0     NaN -0.007796 -0.007796
# 5216316     3.0 2017-12-28 2021-09-30  ...   0.0     NaN -0.010814 -0.010814
# 5216567     3.0 2017-12-28 2021-09-30  ...   0.0     NaN  0.009665  0.009665
# 5216819     3.0 2017-12-28 2021-09-30  ...   0.0     NaN  0.007307  0.007307
# 5217072     3.0 2017-12-28 2021-09-30  ...   0.0     NaN -0.007703 -0.007703
#
#          month  year  1+retadj    annRet  daycount  annRet10
# 5216065     12  2016  0.992204  0.124805       365  0.221092
# 5216316     12  2017  0.989186  0.484747       363  0.445194
# 5216567     12  2018  1.009665 -0.053916       365 -0.081593
# 5216819     12  2019  1.007307  0.889663       365  0.944266
# 5217072     12  2020  0.992297  0.823096       366  0.729007
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Export

# %%
crsp3.annRet.describe()
# Out:
# count    171032.000000
# mean          0.158212
# std           0.983966
# min          -1.000000
# 25%          -0.251010
# 50%           0.038523
# 75%           0.350889
# max         110.599789
# Name: annRet, dtype: float64

# %%
crsp3.annRet10.describe()
# Out:
# count    171032.000000
# mean          0.136185
# std           0.899211
# min          -1.000000
# 25%          -0.256937
# 50%           0.033964
# 75%           0.336286
# max         114.448125
# Name: annRet10, dtype: float64

# %%
crsp3.to_csv("AnnRet.csv.gz", 
           index=False, 
           compression="gzip")

# %% [markdown]
# #### Apple Check

# %%
crsp3[(crsp3['permno']==14593)&(crsp3['year']==2019)]
# Out:
#          permno  permco       ret      retx     shrout        prc  shrcd  \
# 4945768   14593       7  0.007307  0.007307  4384959.0  293.64999   11.0
#
#          exchcd     namedt   nameendt  ... dlret  dlstdt    retadj   retxadj  \
# 4945768     3.0 2017-12-28 2021-09-30  ...   0.0     NaN  0.007307  0.007307
#
#          month  year  1+retadj    annRet  daycount  annRet10
# 4945768     12  2019  1.007307  0.889663       365  0.944266
#
# [1 rows x 21 columns]

# %% [markdown]
# ## QC Annual Returns

# %%
annRet = pd.read_csv('annRtnlagwBeta.csv', usecols=lambda x: x.lower())

annRet.head()
# Out:
#    Unnamed: 0  PERMNO  PERMCO  YEAR TICKER  CompoundRet     wbeta  lag_wBeta
# 0           0   10000    7952  1986  OMFGA    -0.798781  0.552593        NaN
# 1           1   10000    7952  1987  OMFGA    -0.575759 -0.232978   0.552593
# 2           2   10001    7953  1986   GFGC     0.297045  0.034393        NaN
# 3           3   10001    7953  1987   GFGC    -0.098984  0.123460   0.034393
# 4           4   10001    7953  1988   GFGC     0.160856  0.332379   0.123460

# %%
annRet[annRet['PERMNO']==70519]
# Out:
#         Unnamed: 0  PERMNO  PERMCO  YEAR TICKER  CompoundRet     wbeta  \
# 167584      167584   70519   20483  1986    CCC    -0.021035  0.449165
# 167585      167585   70519   20483  1987    CCC     0.101848  1.063682
# 167586      167586   70519   20483  1988    CCC    -0.017245  1.006637
# 167587      167587   70519   20483  1989    CCC     0.028735  1.319353
# 167588      167588   70519   20483  1989     PA     0.325624  1.319353
# 167589      167589   70519   20483  1990     PA    -0.185677  1.277405
# 167590      167590   70519   20483  1991     PA     0.747234  1.307438
# 167591      167591   70519   20483  1992     PA     0.250353  1.438842
# 167592      167592   70519   20483  1993     PA     0.629590  1.586171
# 167593      167593   70519   20483  1994    TRV    -0.153872  1.487769
# 167594      167594   70519   20483  1995    TRV     0.977246  1.691658
# 167595      167595   70519   20483  1996    TRV     0.468668  1.652075
# 167596      167596   70519   20483  1997    TRV     0.798656  1.630644
# 167597      167597   70519   20483  1998      C    -0.068285  1.653761
# 167598      167598   70519   20483  1998    CCI    -0.096414  1.653761
# 167599      167599   70519   20483  1998    TRV    -0.406990  1.653761
# 167600      167600   70519   20483  1999      C     0.700787  1.457505
# 167601      167601   70519   20483  2000      C     0.235735  1.211992
# 167602      167602   70519   20483  2001      C     0.000334  1.355172
# 167603      167603   70519   20483  2002      C    -0.243402  1.562924
# 167604      167604   70519   20483  2003      C     0.415783  1.198247
# 167605      167605   70519   20483  2004      C     0.027232  1.102867
# 167606      167606   70519   20483  2005      C     0.046290  0.709659
# 167607      167607   70519   20483  2006      C     0.195509  0.917969
# 167608      167608   70519   20483  2007      C    -0.447089  1.373525
# 167609      167609   70519   20483  2008      C    -0.759760  1.805241
# 167610      167610   70519   20483  2009      C    -0.505444  2.376157
# 167611      167611   70519   20483  2010      C     0.429008  1.407527
# 167612      167612   70519   20483  2011      C    -0.443302  1.926463
# 167613      167613   70519   20483  2012      C     0.505515  2.010708
# 167614      167614   70519   20483  2013      C     0.318359  1.545168
# 167615      167615   70519   20483  2014      C     0.039218  1.225973
# 167616      167616   70519   20483  2015      C    -0.040808  1.283719
# 167617      167617   70519   20483  2016      C     0.159069  1.877554
# 167618      167618   70519   20483  2017      C     0.270397  1.518017
# 167619      167619   70519   20483  2018      C    -0.284920  1.041166
# 167620      167620   70519   20483  2019      C     0.577799  1.490049
# 167621      167621   70519   20483  2020      C    -0.196398  1.544366
# 167622      167622   70519   20483  2021      C     0.165131  1.000174
#
#         lag_wBeta
# 167584        NaN
# 167585   0.449165
# 167586   1.063682
# 167587   1.006637
# 167588   1.319353
# 167589   1.319353
# 167590   1.277405
# 167591   1.307438
# 167592   1.438842
# 167593   1.586171
# 167594   1.487769
# 167595   1.691658
# 167596   1.652075
# 167597   1.630644
# 167598   1.653761
# 167599   1.653761
# 167600   1.653761
# 167601   1.457505
# 167602   1.211992
# 167603   1.355172
# 167604   1.562924
# 167605   1.198247
# 167606   1.102867
# 167607   0.709659
# 167608   0.917969
# 167609   1.373525
# 167610   1.805241
# 167611   2.376157
# 167612   1.407527
# 167613   1.926463
# 167614   2.010708
# 167615   1.545168
# 167616   1.225973
# 167617   1.283719
# 167618   1.877554
# 167619   1.518017
# 167620   1.041166
# 167621   1.490049
# 167622   1.544366
