# %% [markdown]
# ## Performance of Value Weighted Portfolio
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from dateutil.relativedelta import *
from pandas.tseries.offsets import *
from scipy import stats
import statsmodels.api as sm
import statistics
import pickle
import sys
sys.path.insert(0, "../")
import util
from importlib import reload
util=reload(util)

# %% [markdown]
# ### Set Local Macro Variables

# %%
start = 2010

# %% [markdown]
# ### Import Data
# #### Equal Weighted Sample Portfolio

# %%
port = pd.read_csv('vw_sample_port.csv.gz', compression='gzip', usecols=lambda x: x.lower())

port['jdate'] = pd.to_datetime(port['jdate'])

port.head()
# Out:
#        jdate     vwret   vwret10
# 0 2000-12-31 -0.204483 -0.162944
# 1 2001-12-31  0.051296 -0.014395
# 2 2002-12-31 -0.453449 -0.511883
# 3 2003-12-31  0.589581  0.412401
# 4 2004-12-31 -0.013856 -0.061873

# %%
port['year'] = port['jdate'].dt.year

# %% [markdown]
# #### S&P 500

# %%
crsp_sp = pd.read_csv('qcrsp500d_raw.csv.gz', compression='gzip', usecols=lambda x: x.lower())

crsp_sp = crsp_sp.rename(columns={'caldt':'date'})
crsp_sp['date'] = pd.to_datetime(crsp_sp['date'])

crsp_sp.head()
# Out:
#         date    vwretd    vwretx    ewretd    ewretx      totval  totcnt  \
# 0 1925-12-31       NaN       NaN       NaN       NaN  15236829.5    89.0
# 1 1926-01-02  0.004297  0.004297  0.002941  0.002941  15319686.5    89.0
# 2 1926-01-04 -0.001357 -0.001357  0.001036  0.001036  15298901.2    89.0
# 3 1926-01-05 -0.004603 -0.004653 -0.005856 -0.006063  15227711.5    89.0
# 4 1926-01-06  0.000537  0.000537  0.000888  0.000888  15235889.2    89.0
#
#        usdval  usdcnt  spindx  sprtrn
# 0         NaN     NaN     NaN     NaN
# 1  15236829.5    79.0     NaN     NaN
# 2  15319686.5    80.0     NaN     NaN
# 3  15298901.2    80.0     NaN     NaN
# 4  15227711.5    80.0     NaN     NaN

# %%
# Annual S&P 500 Returns
df=crsp_sp
df=df.sort_values(['date'],ascending=True)
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['day'] = df['date'].dt.day
df['1+sprtrn']=df['sprtrn']+1
df['annRet'] = df.groupby(['year'])['1+sprtrn'].cumprod()-1
df=df[df['month']==12]
#df=df[df['day']==31]
crsp_sp = df

# %%
annRet_sp =pd.DataFrame(columns=['year','sp_ret'])

for y in range (start,2021):
     annRet_sp = annRet_sp.append({'year':y,
                                   'sp_ret':crsp_sp.loc[(crsp_sp['year'] == y),'annRet'].values[-1]},
                                   ignore_index=True)
    
annRet_sp.head()
# Out:
#      year    sp_ret
# 0  2010.0  0.127827
# 1  2011.0 -0.000032
# 2  2012.0  0.134057
# 3  2013.0  0.296013
# 4  2014.0  0.113906

# %%
perf = pd.merge(annRet_sp,port,'left','year').drop(columns = ['jdate'])

perf.head()
# Out:
#      year    sp_ret     vwret   vwret10
# 0  2010.0  0.127827  0.369351  0.259867
# 1  2011.0 -0.000032 -0.158535 -0.153788
# 2  2012.0  0.134057  0.202314  0.148435
# 3  2013.0  0.296013  0.526181  0.477743
# 4  2014.0  0.113906  0.088100  0.086179

# %%
perf.columns = (['year','sp_ret','port_ret', 'port_ret10'])

# %%
# Calculate cumulative returns
perf['1+sp_ret'] = perf['sp_ret']+1
perf['1+port_ret'] = perf['port_ret']+1
perf['1+port_ret10'] = perf['port_ret10']+1
perf['total_sp_ret'] = (perf['1+sp_ret'].cumprod()-1)*100
perf['total_port_ret'] = (perf['1+port_ret'].cumprod()-1)*100
perf['total_port_ret10'] = (perf['1+port_ret10'].cumprod()-1)*100
perf['total_sp_ret'] = ((perf['1+sp_ret'].cumprod()-1)*100).round(3)
perf['total_port_ret'] = ((perf['1+port_ret'].cumprod()-1)*100).round(3)

# %%
perf['ab_ret']=perf['port_ret']-perf['sp_ret']
perf['ab_ret10']=perf['port_ret10']-perf['sp_ret']

perf.head()
# Out:
#      year    sp_ret  port_ret  port_ret10  1+sp_ret  1+port_ret  1+port_ret10  \
# 0  2010.0  0.127827  0.369351    0.259867  1.127827    1.369351      1.259867
# 1  2011.0 -0.000032 -0.158535   -0.153788  0.999968    0.841465      0.846212
# 2  2012.0  0.134057  0.202314    0.148435  1.134057    1.202314      1.148435
# 3  2013.0  0.296013  0.526181    0.477743  1.296013    1.526181      1.477743
# 4  2014.0  0.113906  0.088100    0.086179  1.113906    1.088100      1.086179
#
#    total_sp_ret  total_port_ret  total_port_ret10    ab_ret  ab_ret10
# 0        12.783          36.935         25.986678  0.241524  0.132040
# 1        12.779          15.226          6.611413 -0.158504 -0.153756
# 2        27.898          38.538         22.436278  0.068257  0.014378
# 3        65.757         111.434         80.929412  0.230168  0.181731
# 4        84.638         130.061         96.521683 -0.025806 -0.027728

# %% [markdown]
# ### Plot Portfolio Performance

# %%
plt.plot(perf['year'],perf['total_sp_ret'],label = 'S&P 500')
plt.plot(perf['year'],perf['total_port_ret'],label = 'Portfolio')
plt.plot(perf['year'],perf['total_port_ret10'],label = 'Portfolio (Jan 10)')
plt.legend()
#plt.yscale('log')
plt.ylabel('Cumulative Returns (%)')
plt.title('Portfolio Performance')
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size
plt.show()

# %%
plt.plot(perf['year'],perf['total_port_ret'],label = 'Portfolio',color = 'orange')
plt.plot(perf['year'],perf['total_port_ret10'],label = 'Portfolio (Jan 10)',color = 'green')
plt.legend()
#plt.yscale('log')
plt.ylabel('Cumulative Returns (%)')
plt.title('Portfolio Performance')
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size
plt.show()

# %%
perf
# Out:
#       year    sp_ret  port_ret  port_ret10  1+sp_ret  1+port_ret  \
# 0   2010.0  0.127827  0.369351    0.259867  1.127827    1.369351
# 1   2011.0 -0.000032 -0.158535   -0.153788  0.999968    0.841465
# 2   2012.0  0.134057  0.202314    0.148435  1.134057    1.202314
# 3   2013.0  0.296013  0.526181    0.477743  1.296013    1.526181
# 4   2014.0  0.113906  0.088100    0.086179  1.113906    1.088100
# 5   2015.0 -0.007266 -0.022544   -0.019201  0.992734    0.977456
# 6   2016.0  0.095350  0.158222    0.300727  1.095350    1.158222
# 7   2017.0  0.194200  0.319656    0.285390  1.194200    1.319656
# 8   2018.0 -0.062373 -0.181415   -0.209083  0.937627    0.818585
# 9   2019.0  0.288781  0.355349    0.312137  1.288781    1.355349
# 10  2020.0  0.162589  0.464782    0.413785  1.162589    1.464782
#
#     1+port_ret10  total_sp_ret  total_port_ret  total_port_ret10    ab_ret  \
# 0       1.259867        12.783          36.935         25.986678  0.241524
# 1       0.846212        12.779          15.226          6.611413 -0.158504
# 2       1.148435        27.898          38.538         22.436278  0.068257
# 3       1.477743        65.757         111.434         80.929412  0.230168
# 4       1.086179        84.638         130.061         96.521683 -0.025806
# 5       0.980799        83.297         124.875         92.748190 -0.015278
# 6       1.300727       100.774         160.455        150.712814  0.062871
# 7       1.285390       139.764         243.710        222.263626  0.125456
# 8       0.790917       124.809         181.356        154.883807 -0.119043
# 9       1.312137       189.730         281.336        234.442371  0.066568
# 10      1.413785       236.837         458.574        372.829656  0.302193
#
#     ab_ret10
# 0   0.132040
# 1  -0.153756
# 2   0.014378
# 3   0.181731
# 4  -0.027728
# 5  -0.011935
# 6   0.205377
# 7   0.091190
# 8  -0.146710
# 9   0.023356
# 10  0.251196

# %%
print('Low Beta Value-Weighted Portfolio Return: ', round(perf["port_ret"].mean(), 3))
print('Low Beta Value-Weighted Portfolio Return (Jan 10): ', round(perf["port_ret10"].mean(), 3))
# Out:
# Low Beta Value-Weighted Portfolio Return:  0.193
# Low Beta Value-Weighted Portfolio Return (Jan 10):  0.173

# %%
print('Low Beta Sharpe Ratio: ', round(perf["port_ret"].mean()/perf["port_ret"].std(), 3))
print('Low Beta Sharpe Ratio (Jan 10): ', round(perf["port_ret10"].mean()/perf["port_ret10"].std(), 3))
# Out:
# Low Beta Sharpe Ratio:  0.8
# Low Beta Sharpe Ratio (Jan 10):  0.77

# %%
df_perf = perf[['year', 'port_ret', 'port_ret10', 'sp_ret']].round(3)
df_perf.columns = (['Year', 'Low Beta Portfolio Return', 'Low Beta Portfolio Return - Jan Effect', 'S&P 500 Return'])
df_perf
# Out:
#       Year  Low Beta Portfolio Return  Low Beta Portfolio Return - Jan Effect  \
# 0   2010.0                      0.369                                   0.260
# 1   2011.0                     -0.159                                  -0.154
# 2   2012.0                      0.202                                   0.148
# 3   2013.0                      0.526                                   0.478
# 4   2014.0                      0.088                                   0.086
# 5   2015.0                     -0.023                                  -0.019
# 6   2016.0                      0.158                                   0.301
# 7   2017.0                      0.320                                   0.285
# 8   2018.0                     -0.181                                  -0.209
# 9   2019.0                      0.355                                   0.312
# 10  2020.0                      0.465                                   0.414
#
#     S&P 500 Return
# 0            0.128
# 1           -0.000
# 2            0.134
# 3            0.296
# 4            0.114
# 5           -0.007
# 6            0.095
# 7            0.194
# 8           -0.062
# 9            0.289
# 10           0.163

# %% [markdown]
# ### Export

# %%
perf.to_csv('vw_perf.csv')
