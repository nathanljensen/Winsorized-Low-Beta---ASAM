# %%
import pandas as pd

# %%
AnnRet = pd.read_csv('AnnRet.csv.gz', compression='gzip')

AnnRet.head()
# Out:
#    permno  permco       ret      retx  shrout     prc  shrcd  exchcd  \
# 0   10001    7953  0.000000  0.000000  1054.0  -9.500   11.0     3.0
# 1   10001    7953 -0.025210 -0.025210  1075.0  14.500   11.0     3.0
# 2   10001    7953 -0.017544 -0.017544  1080.0  14.000   11.0     3.0
# 3   10001    7953 -0.006757 -0.006757  1091.0 -18.375   11.0     3.0
# 4   10001    7953 -0.030303 -0.030303  2224.0   8.000   11.0     3.0
#
#        namedt    nameendt  ... dlret  dlstdt    retadj   retxadj  month  year  \
# 0  1986-01-09  1993-11-21  ...   0.0     NaN  0.000000  0.000000     12  1990
# 1  1986-01-09  1993-11-21  ...   0.0     NaN -0.025210 -0.025210     12  1991
# 2  1986-01-09  1993-11-21  ...   0.0     NaN -0.017544 -0.017544     12  1992
# 3  1993-11-22  2004-06-09  ...   0.0     NaN -0.006757 -0.006757     12  1993
# 4  1993-11-22  2004-06-09  ...   0.0     NaN -0.030303 -0.030303     12  1994
#
#    1+retadj    annRet  daycount  annRet10
# ...

# %%
AnnRet.to_csv('AnnRet.csv')
